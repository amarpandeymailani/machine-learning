# %%
import pandas as pd

# %%
df = pd.read_json ('news_category_dataset.json',lines=True)
#df

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (124989, 6)

# %%
df.category.unique()
# Out:
# array(['CRIME', 'ENTERTAINMENT', 'WORLD NEWS', 'IMPACT', 'POLITICS',
#        'WEIRD NEWS', 'BLACK VOICES', 'WOMEN', 'COMEDY', 'QUEER VOICES',
#        'SPORTS', 'BUSINESS', 'TRAVEL', 'MEDIA', 'TECH', 'RELIGION',
#        'SCIENCE', 'LATINO VOICES', 'EDUCATION', 'COLLEGE', 'PARENTS',
#        'ARTS & CULTURE', 'STYLE', 'GREEN', 'TASTE', 'HEALTHY LIVING',
#        'THE WORLDPOST', 'GOOD NEWS', 'WORLDPOST', 'FIFTY', 'ARTS'],
#       dtype=object)

# %%
df.set_index('category',  inplace = True)
df
# Out:
#                                                 short_description  ...                                            authors
# category                                                           ...
# CRIME           She left her husband. He killed their children...  ...                                    Melissa Jeltsen
# ENTERTAINMENT                            Of course it has a song.  ...                                      Andy McDonald
# ENTERTAINMENT   The actor and his longtime girlfriend Anna Ebe...  ...                                         Ron Dicker
# ENTERTAINMENT   The actor gives Dems an ass-kicking for not fi...  ...                                         Ron Dicker
# ENTERTAINMENT   The "Dietland" actress said using the bags is ...  ...                                         Ron Dicker
# ...                                                           ...  ...                                                ...
# WOMEN                                                              ...
# TASTE           I often hear people describe cooking for one a...  ...         Food Riot, ContributorPlay with your food.
# CRIME                                                              ...  Robert Siciliano, ContributorPersonal Security...
# MEDIA                                                              ...                                     Katherine Fung
# HEALTHY LIVING  Our thoughts and feelings are powerful, but ma...  ...  Mindy Utay, Contributor"Calming Life's Conflicts"
#
# [124989 rows x 5 columns]

# %%
df.shape
# Out:
# (124989, 5)

# %%
df1 = df.loc[['BUSINESS','COMEDY','CRIME','SPORTS','RELIGION','POLITICS','HEALTHY LIVING']]

# %%
df1
# Out:
#                                                 short_description  ...                                            authors
# category                                                           ...
# BUSINESS        The investigation could lead to new U.S. tarif...  ...           David Shepardson and Jeff Mason, Reuters
# BUSINESS        The new policy was unveiled weeks after the co...  ...                                Dominique Mosbergen
# BUSINESS        Following the council vote, Amazon’s vice pres...  ...                           Gregory Scruggs, Reuters
# BUSINESS        Victims will be free to go to court -- but a f...  ...                                         Emily Peck
# BUSINESS        The breach is believed to have occurred betwee...  ...                                     Jenna Amatulli
# ...                                                           ...  ...                                                ...
# HEALTHY LIVING  Instead of judging whether you made the right ...  ...  Elizabeth Grace Saunders, ContributorFounder, ...
# HEALTHY LIVING  While there are strong arguments for the games...  ...         Mona Shattell, Contributornurse researcher
# HEALTHY LIVING  My wake-up call marching orders were clear: No...  ...  Jane Shure, ContributorLeadership Coach, Psych...
# HEALTHY LIVING  It is very difficult for some people to see an...  ...  Nancy Colier, ContributorPsychotherapist, inte...
# HEALTHY LIVING  Our thoughts and feelings are powerful, but ma...  ...  Mindy Utay, Contributor"Calming Life's Conflicts"
#
# [57274 rows x 5 columns]

# %%
df1.index.unique()
# Out:
# Index(['BUSINESS', 'COMEDY', 'CRIME', 'SPORTS', 'RELIGION', 'POLITICS',
#        'HEALTHY LIVING'],
#       dtype='object', name='category')

# %%
df2 = df1.reset_index()
df2
# Out:
#              category  ...                                            authors
# 0            BUSINESS  ...           David Shepardson and Jeff Mason, Reuters
# 1            BUSINESS  ...                                Dominique Mosbergen
# 2            BUSINESS  ...                           Gregory Scruggs, Reuters
# 3            BUSINESS  ...                                         Emily Peck
# 4            BUSINESS  ...                                     Jenna Amatulli
# ...               ...  ...                                                ...
# 57269  HEALTHY LIVING  ...  Elizabeth Grace Saunders, ContributorFounder, ...
# 57270  HEALTHY LIVING  ...         Mona Shattell, Contributornurse researcher
# 57271  HEALTHY LIVING  ...  Jane Shure, ContributorLeadership Coach, Psych...
# 57272  HEALTHY LIVING  ...  Nancy Colier, ContributorPsychotherapist, inte...
# 57273  HEALTHY LIVING  ...  Mindy Utay, Contributor"Calming Life's Conflicts"
#
# [57274 rows x 6 columns]

# %%
df2.category.unique()
# Out:
# array(['BUSINESS', 'COMEDY', 'CRIME', 'SPORTS', 'RELIGION', 'POLITICS',
#        'HEALTHY LIVING'], dtype=object)

# %%
df2['category'].value_counts()
# Out:
# POLITICS          32739
# HEALTHY LIVING     6694
# BUSINESS           4254
# SPORTS             4167
# COMEDY             3971
# CRIME              2893
# RELIGION           2556
# Name: category, dtype: int64

# %%
df3 = df2[["category","headline"]]
df3
# Out:
#              category                                           headline
# 0            BUSINESS  U.S. Launches Auto Import Probe, China Vows To...
# 1            BUSINESS  Starbucks Says Anyone Can Now Sit In Its Cafes...
# 2            BUSINESS  Seattle Passes Controversial New Tax On City's...
# 3            BUSINESS  Uber Ends Forced Arbitration In Individual Cas...
# 4            BUSINESS  Chili's Hit By Data Breach, Credit And Debit C...
# ...               ...                                                ...
# 57269  HEALTHY LIVING  Why You Need Both a 'Bouncer' and a 'Bartender...
# 57270  HEALTHY LIVING  How Video Games Can Improve Dialogue on Mental...
# 57271  HEALTHY LIVING  Wake-Up Calls Inspired My Change From Overdriv...
# 57272  HEALTHY LIVING        Loving a Narcissist Without Losing Yourself
# 57273  HEALTHY LIVING                            Reasons Not to Be Happy
#
# [57274 rows x 2 columns]

# %%
import string
df3['category']=df3.category.map({'BUSINESS':1,'COMEDY':2,'CRIME':3,'SPORTS':4,'RELIGION':5,'POLITICS':6,'HEALTHY LIVING':7})
df3['headline'] = df3.headline.map(
    lambda x: x.lower().translate(str.maketrans('','', string.punctuation))
)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df3
# Out:
#        category                                           headline
# 0             1  us launches auto import probe china vows to de...
# 1             1  starbucks says anyone can now sit in its cafes...
# 2             1  seattle passes controversial new tax on citys ...
# 3             1  uber ends forced arbitration in individual cas...
# 4             1  chilis hit by data breach credit and debit car...
# ...         ...                                                ...
# 57269         7  why you need both a bouncer and a bartender to...
# 57270         7  how video games can improve dialogue on mental...
# 57271         7  wakeup calls inspired my change from overdrive...
# 57272         7        loving a narcissist without losing yourself
# 57273         7                            reasons not to be happy
#
# [57274 rows x 2 columns]

# %%
X=[]
Y=[]
X=df3.iloc[:,1].values
Y=df3.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X, 
    Y,test_size=0.15, 
    random_state = 0
)

# %%
X_train
X_train.shape
# Out:
# (48682,)

# %%
for i in range(1,5):
    print(X_train[i])
# Out:
# jeb bush rewrites the history of the iraq war
# anthony scaramucci prompts search of scaramouch and people cant handle the definition
# jeb bush was not shy about using his white house connections
# huffpost hill  media to cover donald trump speech

# %%
# A list of common english words which should not affect predictions
# manually entering stopwords or we can also use library like nltk
stopwords = ['a', 'about', 'above', 'across', 'after', 'afterwards', 'again', 'against', 'all', 'almost', 'alone',
             'along', 'already', 'also', 'although', 'always', 'am', 'among', 'amongst', 'amoungst', 'amount',
             'an', 'and', 'another', 'any', 'anyhow', 'anyone', 'anything', 'anyway', 'anywhere', 'are', 'around',
             'as', 'at', 'back', 'be', 'became', 'because', 'become', 'becomes', 'becoming', 'been', 'before',
             'beforehand', 'behind', 'being', 'below', 'beside', 'besides', 'between', 'beyond', 'bill', 'both',
             'bottom', 'but', 'by', 'call', 'can', 'cannot', 'cant', 'co', 'con', 'could', 'couldnt', 'cry', 'de',
             'describe', 'detail', 'did', 'do', 'does', 'doing', 'don', 'done', 'down', 'due', 'during', 'each', 'eg',
             'eight', 'either', 'eleven', 'else', 'elsewhere', 'empty', 'enough', 'etc', 'even', 'ever', 'every', 'everyone',
             'everything', 'everywhere', 'except', 'few', 'fifteen', 'fify', 'fill', 'find', 'fire', 'first', 'five', 'for',
             'former', 'formerly', 'forty', 'found', 'four', 'from', 'front', 'full', 'further', 'get', 'give', 'go', 'had',
             'has', 'hasnt', 'have', 'having', 'he', 'hence', 'her', 'here', 'hereafter', 'hereby', 'herein', 'hereupon',
             'hers', 'herself', 'him', 'himself', 'his', 'how', 'however', 'hundred', 'i', 'ie', 'if', 'in', 'inc', 'indeed',
             'interest', 'into', 'is', 'it', 'its', 'itself', 'just', 'keep', 'last', 'latter', 'latterly', 'least', 'less',
             'ltd', 'made', 'many', 'may', 'me', 'meanwhile', 'might', 'mill', 'mine', 'more', 'moreover', 'most', 'mostly',
             'move', 'much', 'must', 'my', 'myself', 'name', 'namely', 'neither', 'never', 'nevertheless', 'next', 'nine',
             'no', 'nobody', 'none', 'noone', 'nor', 'not', 'nothing', 'now', 'nowhere', 'of', 'off', 'often', 'on', 'once',
             'one', 'only', 'onto', 'or', 'other', 'others', 'otherwise', 'our', 'ours', 'ourselves', 'out', 'over', 'own',
             'part', 'per', 'perhaps', 'please', 'put', 'rather', 're', 's', 'same', 'see', 'seem', 'seemed', 'seeming',
             'seems', 'serious', 'several', 'she', 'should', 'show', 'side', 'since', 'sincere', 'six', 'sixty', 'so', 
             'some', 'somehow', 'someone', 'something', 'sometime', 'sometimes', 'somewhere', 'still', 'such', 'system',
             't', 'take', 'ten', 'than', 'that', 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'thence', 'there',
             'thereafter', 'thereby', 'therefore', 'therein', 'thereupon', 'these', 'they', 'thickv', 'thin', 'third', 'this',
             'those', 'though', 'three', 'through', 'throughout', 'thru', 'thus', 'to', 'together', 'too', 'top', 'toward',
             'towards', 'twelve', 'twenty', 'two', 'un', 'under', 'until', 'up', 'upon', 'us', 'very', 'via', 'was', 'we',
             'well', 'were', 'what', 'whatever', 'when', 'whence', 'whenever', 'where', 'whereafter', 'whereas', 'whereby',
             'wherein', 'whereupon', 'wherever', 'whether', 'which', 'while', 'whither', 'who', 'whoever', 'whole', 'whom',
             'whose', 'why', 'will', 'with', 'within', 'without', 'would', 'yet', 'you', 'your', 'yours', 'yourself',
             'yourselves']

# %%
len(stopwords)
# Out:
# 327

# %%
vocab = {}
for i in range(len(X_train)):
    word_list = []
    for word in X_train[i].split():
        word_new  = word.strip()
        if (len(word_new)>2)  and (word_new not in stopwords):  
            if word_new in vocab:
                vocab[word_new]+=1
            else:
                vocab[word_new]=1
                
vocab
# Out:
# {'trevor': 143,
#  'noah': 142,
#  'donald': 3110,
#  'trump': 6460,
#  'making': 200,
#  'bank': 76,
#  'president': 677,
#  'jeb': 182,
#  'bush': 252,
#  'rewrites': 2,
#  'history': 212,
#  'iraq': 99,
#  'war': 379,
#  'anthony': 60,
#  'scaramucci': 26,
#  'prompts': 14,
#  'search': 57,
#  'scaramouch': 1,
#  'people': 797,
#  'handle': 35,
#  'definition': 8,
#  'shy': 9,
#  'using': 126,
#  'white': 878,
#  'house': 1094,
#  'connections': 14,
#  'huffpost': 411,
#  'hill': 214,
#  'media': 198,
#  'cover': 44,
#  'speech': 246,
#  'espn': 34,
#  'pulls': 44,
#  'broadcaster': 2,
#  'virginia': 125,
#  'game': 252,
#  'robert': 81,
#  'lee': 29,
#  'week': 222,
#  'cheese': 10,
#  'curt': 13,
#  'schilling': 13,
#  'threatens': 72,
#  'run': 242,
#  '2024': 8,
#  'criticism': 53,
#  'benjamin': 3,
#  'netanyahu': 33,
#  'defends': 122,
#  'planned': 169,
#  'congress': 459,
#  'feds': 76,
#  'investigating': 33,
#  'exxon': 32,
#  'climate': 430,
#  'change': 470,
#  'nebraska': 17,
#  'senator': 223,
#  'uses': 81,
#  'gore': 18,
#  'porn': 29,
#  'argue': 10,
#  'restoring': 13,
#  'death': 417,
#  'penalty': 77,
#  'ways': 350,
#  'make': 573,
#  '2016': 368,
#  'better': 253,
#  'women': 620,
#  'girls': 64,
#  'investigation': 139,
#  'underway': 9,
#  'alligators': 1,
#  'eating': 67,
#  'human': 112,
#  'body': 132,
#  'canal': 2,
#  'wtf': 11,
#  'wrong': 208,
#  'poll': 153,
#  'finds': 150,
#  'split': 25,
#  'reactions': 13,
#  'firing': 63,
#  'fbi': 240,
#  'director': 137,
#  'james': 268,
#  'comey': 157,
#  'owe': 6,
#  'hobby': 20,
#  'devil': 7,
#  'know': 582,
#  'chose': 10,
#  'remove': 25,
#  'breasts': 4,
#  'important': 110,
#  'rsvp': 2,
#  'pope': 240,
#  'francis': 145,
#  'obama': 1178,
#  'says': 1399,
#  'hell': 104,
#  'nominate': 21,
#  'successor': 11,
#  'scalia': 39,
#  'expects': 8,
#  'timely': 1,
#  'vote': 384,
#  'searching': 11,
#  'meaning': 27,
#  'tumultuous': 2,
#  'times': 136,
#  'priest': 34,
#  'heres': 496,
#  'thoughts': 54,
#  'prayers': 30,
#  'announces': 92,
#  'new': 1750,
#  'sanctions': 62,
#  'north': 267,
#  'korea': 106,
#  'response': 132,
#  'sony': 7,
#  'hack': 37,
#  'maya': 7,
#  'angelou': 5,
#  'golf': 50,
#  'sensation': 4,
#  'jordan': 29,
#  'spieth': 2,
#  'loses': 70,
#  'masters': 7,
#  'horrible': 23,
#  'meltdown': 12,
#  'danny': 7,
#  'willett': 1,
#  'wins': 226,
#  'hottest': 4,
#  'changethemed': 1,
#  'pickup': 8,
#  'lines': 34,
#  'oregon': 85,
#  'gov': 83,
#  'ryan': 269,
#  'zinke': 22,
#  'conceded': 1,
#  'there’s': 25,
#  'money': 254,
#  'drilling': 33,
#  'coast': 24,
#  'jay': 19,
#  'dickeys': 1,
#  'complicated': 18,
#  'legacy': 75,
#  'lesson': 39,
#  'politicians': 75,
#  'scientists': 48,
#  'alike': 5,
#  'gifts': 20,
#  'anxiety': 70,
#  'really': 427,
#  'want': 411,
#  'holidays': 54,
#  'eat': 60,
#  'work': 300,
#  'half': 58,
#  'unfavorable': 1,
#  'view': 36,
#  'tennessee': 43,
#  'county': 70,
#  'offers': 62,
#  'inmates': 38,
#  'shorter': 4,
#  'sentences': 16,
#  'vasectomy': 1,
#  'san': 122,
#  'franciscos': 4,
#  'transit': 12,
#  'agency': 57,
#  'promises': 66,
#  'immigration': 285,
#  'raids': 17,
#  'massachusetts': 26,
#  'democrats': 639,
#  'compete': 12,
#  'gubernatorial': 23,
#  'primary': 206,
#  'shows': 266,
#  'yale': 7,
#  'isn’t': 53,
#  'climateconscious': 1,
#  'investor': 10,
#  'claims': 212,
#  'jake': 20,
#  'plummer': 2,
#  'slams': 132,
#  'billionaire': 49,
#  'jerry': 51,
#  'jones': 74,
#  'taking': 123,
#  'cte': 12,
#  'seriously': 53,
#  'nate': 6,
#  'robinson': 6,
#  'plans': 129,
#  'play': 91,
#  'nfl': 285,
#  'slam': 38,
#  'dunk': 15,
#  'jewish': 86,
#  'institutions': 8,
#  'bomb': 45,
#  'threats': 75,
#  'days': 197,
#  'copycat': 1,
#  'arrest': 77,
#  'teenage': 12,
#  'boy': 82,
#  'fatally': 48,
#  'shoots': 55,
#  'high': 206,
#  'school': 324,
#  'student': 128,
#  'bedroom': 11,
#  'police': 678,
#  'world': 498,
#  'wait': 44,
#  'mayors': 19,
#  'pledge': 28,
#  'hymnprayer': 1,
#  'election': 562,
#  'backing': 31,
#  'republicans': 685,
#  'century': 37,
#  'cincinnati': 6,
#  'enquirer': 1,
#  'endorses': 92,
#  'hillary': 1127,
#  'clinton': 1350,
#  'paul': 404,
#  'count': 33,
#  'south': 145,
#  'dakota': 63,
#  'government': 224,
#  'employee': 54,
#  'stole': 17,
#  'regulator': 5,
#  'files': 45,
#  'major': 158,
#  'incident': 18,
#  'notre': 10,
#  'dame': 11,
#  'students': 181,
#  'walk': 27,
#  'mike': 252,
#  'pences': 24,
#  'commencement': 13,
#  'greece': 15,
#  'financial': 63,
#  'zombie': 7,
#  'state': 622,
#  'laughs': 7,
#  'booze': 7,
#  'sigh': 3,
#  'relief': 51,
#  'ted': 319,
#  'cruzs': 38,
#  'victory': 117,
#  'party': 301,
#  'evangelical': 34,
#  'halloween': 50,
#  'best': 326,
#  'debate': 389,
#  'probably': 110,
#  'doesnt': 306,
#  'matter': 119,
#  'florida': 225,
#  'man': 615,
#  'plotted': 3,
#  'isisinspired': 3,
#  'backpack': 3,
#  'bombing': 37,
#  'beach': 27,
#  'alabama': 116,
#  'conducts': 4,
#  'voter': 236,
#  'fraud': 147,
#  'based': 22,
#  'mans': 39,
#  'offthecuff': 1,
#  'comment': 25,
#  'photo': 73,
#  'jen': 5,
#  'welter': 4,
#  'sarah': 71,
#  'thomas': 31,
#  'worth': 48,
#  'way': 372,
#  '1000': 21,
#  'words': 79,
#  'legalizations': 2,
#  'march': 129,
#  'continues': 91,
#  'lead': 159,
#  'need': 545,
#  'apologize': 25,
#  'happened': 83,
#  'bible': 31,
#  'wont': 411,
#  'tennessees': 5,
#  'official': 127,
#  'book': 83,
#  'intel': 23,
#  'makes': 241,
#  'huge': 98,
#  'push': 154,
#  'hire': 25,
#  'minorities': 22,
#  'melania': 58,
#  'got': 221,
#  'green': 64,
#  'card': 47,
#  'immigrants': 119,
#  'extraordinary': 8,
#  'abilities': 2,
#  'trumps': 1810,
#  'latest': 171,
#  'hes': 254,
#  'different': 55,
#  'old': 101,
#  'republican': 492,
#  'foes': 8,
#  'nyt': 17,
#  'vetting': 13,
#  'iowa': 152,
#  'judge': 295,
#  'supreme': 507,
#  'court': 764,
#  'seat': 56,
#  'despite': 111,
#  'campaign': 591,
#  'supported': 8,
#  'bailout': 8,
#  'refuses': 56,
#  'accept': 39,
#  'responsibility': 27,
#  'violent': 35,
#  'protesters': 132,
#  'consider': 52,
#  'civil': 125,
#  'rights': 323,
#  'probe': 179,
#  'deadly': 85,
#  'jail': 89,
#  'ally': 20,
#  'sheriff': 72,
#  'david': 104,
#  'clarke': 6,
#  'district': 42,
#  'attorney': 119,
#  'opposed': 15,
#  'legalization': 30,
#  'charge': 60,
#  'implementing': 1,
#  'marijuana': 180,
#  'regulations': 21,
#  'senate': 641,
#  'dems': 80,
#  'trump’s': 370,
#  'epa': 140,
#  'pick': 170,
#  '‘fullfledged': 1,
#  'environmental': 42,
#  'emergency': 59,
#  'charged': 139,
#  'killing': 141,
#  'wife': 95,
#  'years': 417,
#  'plummeted': 2,
#  'smith': 40,
#  'ejected': 4,
#  'vicious': 12,
#  'hit': 124,
#  'celtics': 5,
#  'players': 115,
#  'face': 250,
#  'kids': 231,
#  'fail': 57,
#  'adorably': 3,
#  'explaining': 9,
#  'adultery': 1,
#  'jimmy': 258,
#  'kimmel': 125,
#  'live': 246,
#  'travel': 165,
#  'reviews': 14,
#  'trustworthy': 4,
#  'hotels': 12,
#  'provide': 20,
#  'paid': 90,
#  'maternity': 13,
#  'leave': 129,
#  'ivanka': 80,
#  'claim': 105,
#  'freak': 13,
#  'learning': 36,
#  'reagan': 24,
#  'decree': 1,
#  'protects': 11,
#  'lois': 7,
#  'lerner': 4,
#  'business': 427,
#  'malyn': 1,
#  'joplin': 1,
#  'founder': 56,
#  'pearl': 8,
#  'report': 461,
#  'alleges': 17,
#  'abuses': 6,
#  'dhs': 28,
#  'facilities': 4,
#  'mexican': 33,
#  'border': 141,
#  'presses': 13,
#  'russia': 307,
#  'syria': 101,
#  'delay': 20,
#  'removal': 17,
#  'chemical': 20,
#  'weapons': 43,
#  'lakers': 19,
#  'fan': 88,
#  'like': 607,
#  'screw': 15,
#  'puts': 60,
#  'warriors': 37,
#  'jersey': 53,
#  'midgame': 2,
#  'food': 189,
#  'swaps': 4,
#  'sleep': 218,
#  'thefuturein5': 4,
#  'episode': 17,
#  'biggest': 115,
#  'barrier': 8,
#  'path': 43,
#  'trouble': 41,
#  'chicago': 114,
#  'brothers': 50,
#  'parole': 7,
#  'murder': 121,
#  'nba': 141,
#  'stars': 50,
#  'cousin': 7,
#  'rnc': 90,
#  'delegates': 29,
#  'antidote': 6,
#  'michelle': 73,
#  'cargo': 9,
#  'shorts': 9,
#  'awareness': 30,
#  'arizona': 75,
#  'supporting': 39,
#  'isis': 169,
#  'rachel': 12,
#  'skozas': 1,
#  'gps': 96,
#  'guide': 180,
#  'life': 468,
#  'comes': 118,
#  'beckham': 9,
#  'gives': 134,
#  '100000': 13,
#  'shocked': 21,
#  'family': 219,
#  'salmonella': 8,
#  'cucumbers': 1,
#  'sickened': 2,
#  '341': 1,
#  'update': 68,
#  'cop': 136,
#  'involved': 20,
#  'mass': 132,
#  'shooting': 482,
#  'juan': 8,
#  'pablo': 1,
#  'montoya': 1,
#  'second': 124,
#  'indianapolis': 8,
#  '500': 13,
#  'rethinking': 7,
#  'personal': 78,
#  'growth': 41,
#  'management': 29,
#  'interview': 129,
#  'growally': 1,
#  'ceo': 165,
#  'viviana': 1,
#  'vethencourt': 1,
#  'quits': 30,
#  'board': 77,
#  'posts': 23,
#  'ahead': 112,
#  'possible': 99,
#  'compares': 34,
#  'harvey': 76,
#  'weinstein': 23,
#  'hamilton': 20,
#  'boos': 4,
#  'twitter': 313,
#  'users': 52,
#  'nameapencemusical': 1,
#  'antiimmigrant': 17,
#  'hate': 145,
#  'targets': 31,
#  'asians': 8,
#  'virginians': 4,
#  'respond': 21,
#  'day': 568,
#  'koch': 53,
#  'nonprofit': 35,
#  'president’s': 2,
#  'antinet': 1,
#  'neutrality': 44,
#  'universally': 2,
#  'gross': 16,
#  'things': 304,
#  'talks': 83,
#  'share': 34,
#  'theyll': 13,
#  'miss': 46,
#  'americas': 141,
#  'mom': 113,
#  'signs': 97,
#  'memorandum': 1,
#  'ending': 44,
#  'catch': 44,
#  'release': 97,
#  'policy': 209,
#  'holiday': 102,
#  'blues': 13,
#  'beat': 70,
#  'overspending': 1,
#  'right': 307,
#  'dose': 6,
#  'exercise': 44,
#  'aging': 9,
#  'brain': 109,
#  'group': 217,
#  'outcast': 1,
#  'teen': 144,
#  'boys': 20,
#  'taught': 33,
#  'value': 25,
#  'youth': 30,
#  'sports': 120,
#  'aide': 62,
#  'denies': 71,
#  'posed': 6,
#  'spokesman': 16,
#  'sitting': 27,
#  'george': 113,
#  'washington': 193,
#  'colin': 40,
#  'kaepernick': 29,
#  'son': 109,
#  'bitches': 3,
#  'gop': 1410,
#  'prospect': 7,
#  'kevin': 49,
#  'cramer': 2,
#  'decides': 30,
#  'afraid': 28,
#  'actually': 198,
#  'states': 362,
#  'lean': 3,
#  'medicaid': 74,
#  'expansion': 22,
#  'potential': 58,
#  'allies': 39,
#  'condemns': 32,
#  'brutal': 35,
#  'boris': 3,
#  'nemtsov': 1,
#  'lawmaker': 94,
#  'urges': 69,
#  'cabinet': 55,
#  'undergo': 2,
#  'mental': 148,
#  'health': 898,
#  'evaluation': 3,
#  'decades': 38,
#  'sexual': 234,
#  'abuse': 152,
#  'elite': 16,
#  'connecticut': 27,
#  'documented': 3,
#  'prescription': 17,
#  'america': 469,
#  'religious': 134,
#  'freedom': 112,
#  'law': 336,
#  'condemned': 8,
#  'discriminatory': 9,
#  'evan': 8,
#  'bayh': 4,
#  'meeting': 131,
#  'russian': 183,
#  'lawyer': 133,
#  'alarming': 10,
#  'revelation': 3,
#  'jared': 77,
#  'kushner': 66,
#  'calls': 417,
#  'muslim': 262,
#  '‘terrorists’': 1,
#  'nyc': 68,
#  'subway': 23,
#  'gets': 316,
#  'shut': 64,
#  'ignore': 32,
#  'convert': 4,
#  'craziness': 1,
#  'oppose': 38,
#  'ignorance': 9,
#  'canada': 39,
#  'islam': 38,
#  'launches': 48,
#  'fine': 43,
#  'antibullying': 2,
#  '401k': 3,
#  'millionaire': 7,
#  'mtv': 3,
#  'cribsstyle': 1,
#  'tour': 26,
#  'pluto': 2,
#  'israel': 63,
#  'eavesdropped': 1,
#  'john': 512,
#  'kerry': 46,
#  'mideast': 8,
#  'sit': 14,
#  'getting': 220,
#  'rncs': 7,
#  'vendors': 1,
#  'crushing': 6,
#  'mitt': 69,
#  'romneys': 9,
#  '2012': 19,
#  'performance': 38,
#  'daily': 212,
#  'meditation': 163,
#  'eid': 5,
#  'mubarak': 2,
#  'alarmed': 8,
#  'reports': 88,
#  'military': 142,
#  'families': 98,
#  'harassed': 8,
#  'minihabits': 1,
#  'immediately': 22,
#  'university': 86,
#  'absolute': 11,
#  'conflict': 30,
#  'mitch': 103,
#  'mcconnell': 128,
#  'thousands': 93,
#  'gather': 18,
#  'mourn': 11,
#  'otto': 4,
#  'warmbier': 4,
#  'assault': 146,
#  'journalism': 18,
#  'building': 70,
#  'knowledge': 7,
#  'protect': 105,
#  'expression': 7,
#  'super': 270,
#  'pacs': 18,
#  'facebook': 133,
#  'ads': 77,
#  'roy': 143,
#  'moore': 146,
#  'doug': 35,
#  'supports': 38,
#  'kneelers': 2,
#  'rise': 265,
#  'news': 370,
#  'november': 54,
#  '24th': 1,
#  'ashamed': 12,
#  'tending': 1,
#  'elections': 71,
#  'authorization': 16,
#  'dreamer': 21,
#  'sues': 76,
#  'federal': 282,
#  'help': 426,
#  'millions': 91,
#  'expanded': 10,
#  'myth': 23,
#  'country': 144,
#  'repairing': 2,
#  'breach': 18,
#  'mondays': 78,
#  'morning': 422,
#  'email': 506,
#  'expect': 43,
#  'mueller': 98,
#  'indictment': 12,
#  'looms': 22,
#  'nazish': 1,
#  'aslam': 1,
#  'forwhereiam': 1,
#  'telecom': 2,
#  'sleaze': 2,
#  'alec': 32,
#  'communications': 20,
#  'funders': 1,
#  'att': 16,
#  'verizon': 23,
#  'centurylink': 1,
#  'comcast': 7,
#  'time': 562,
#  'warner': 19,
#  'cable': 19,
#  'issue': 79,
#  'manchester': 12,
#  'attacker': 13,
#  'believe': 73,
#  'city': 212,
#  'apartment': 7,
#  'build': 55,
#  'loyalty': 8,
#  'cost': 83,
#  '0000': 1,
#  'person': 86,
#  'disability': 20,
#  'challenging': 12,
#  'woman': 324,
#  'adds': 19,
#  'extra': 14,
#  'challenges': 41,
#  'content': 23,
#  'turn': 95,
#  'away': 155,
#  'visitor': 5,
#  'ambassador': 47,
#  'recalled': 16,
#  'airbnb': 15,
#  'executives': 17,
#  'misadventure': 1,
#  'dear': 62,
#  'voters': 312,
#  'watching': 40,
#  'stanford': 9,
#  'mormon': 20,
#  'church': 144,
#  'end': 265,
#  'centurylong': 1,
#  'relationship': 48,
#  'scouts': 12,
#  'brooklyn': 25,
#  'pizza': 30,
#  'joint': 20,
#  'nixes': 4,
#  'obamacare': 424,
#  'fee': 5,
#  'reportedly': 165,
#  'considering': 34,
#  'fast': 60,
#  'labor': 100,
#  'secretary': 179,
#  'imagination': 8,
#  'fusion': 10,
#  'petitions': 5,
#  'juvenile': 7,
#  'solitary': 17,
#  'confinement': 12,
#  'previews': 4,
#  'documentary': 19,
#  'lobby': 39,
#  'offer': 49,
#  'leno': 6,
#  'takes': 223,
#  'tonight': 31,
#  'monologue': 12,
#  'tell': 144,
#  'harassment': 97,
#  'jokes': 58,
#  'anorexia': 5,
#  'let': 155,
#  'connecting': 4,
#  'dots': 3,
#  'americans': 519,
#  'favor': 31,
#  'gun': 458,
#  'control': 186,
#  'arent': 121,
#  'optimistic': 10,
#  'sudden': 10,
#  'implosion': 4,
#  'secret': 167,
#  'reveal': 50,
#  'silicon': 16,
#  'valley': 18,
#  'touch': 16,
#  'losing': 86,
#  'hires': 18,
#  'hitman': 1,
#  'grandkids': 4,
#  'lice': 2,
#  'say': 543,
#  'wrote': 28,
#  'benghazi': 60,
#  'mother': 85,
#  'review': 65,
#  'cops': 215,
#  'warrant': 9,
#  'obtain': 5,
#  'phones': 10,
#  'location': 6,
#  'watch': 393,
#  'maher': 129,
#  'racists': 16,
#  'liam': 1,
#  'neeson': 1,
#  'sinister': 4,
#  'santa': 20,
#  'claus': 7,
#  'nightmares': 17,
#  'brutalist': 1,
#  '2016s': 7,
#  'democratic': 391,
#  'contenders': 13,
#  'named': 38,
#  'hidden': 30,
#  'extremism': 16,
#  'union': 154,
#  'soon': 45,
#  'able': 20,
#  'afford': 25,
#  'foods': 32,
#  'attempted': 14,
#  'failed': 66,
#  'rescue': 27,
#  'american': 424,
#  'hostages': 6,
#  'distorted': 5,
#  'whats': 133,
#  'going': 215,
#  'usual': 10,
#  'strategic': 13,
#  'planning': 38,
#  'orphan': 1,
#  'chuck': 70,
#  'todd': 13,
#  'questions': 155,
#  'wisdom': 29,
#  'roger': 46,
#  'ailes': 11,
#  'boehners': 7,
#  'plan': 413,
#  'sue': 74,
#  'opensecrets': 1,
#  'data': 96,
#  'executive': 109,
#  'branch': 10,
#  'finances': 8,
#  'officials': 150,
#  'file': 18,
#  'disclosures': 6,
#  'goes': 141,
#  'inside': 145,
#  'womens': 141,
#  'restroom': 3,
#  'fyi': 1,
#  'meets': 49,
#  'baby': 92,
#  'perfect': 119,
#  'wages': 20,
#  'islamic': 58,
#  'aka': 9,
#  'isil': 6,
#  'anatomy': 2,
#  'disaster': 58,
#  'details': 56,
#  'emerge': 14,
#  'suspected': 45,
#  'bomber': 8,
#  'ahmad': 7,
#  'khan': 34,
#  'rahami': 5,
#  'national': 311,
#  'security': 257,
#  'adviser': 82,
#  'bolton': 15,
#  'dangerous': 84,
#  'remembered': 4,
#  'follow': 35,
#  'results': 81,
#  'caucuses': 18,
#  'avoiding': 18,
#  'dehydration': 4,
#  'vital': 12,
#  'ask': 106,
#  'hike': 21,
#  'soldiers': 27,
#  'reassigned': 2,
#  'bringing': 25,
#  'hotel': 47,
#  'pence': 155,
#  'huffpollster': 247,
#  'bernie': 621,
#  'sanders': 711,
#  'chances': 23,
#  'depend': 8,
#  'convincing': 5,
#  'supporters': 172,
#  'justice': 302,
#  'kennedy': 21,
#  'stonewalled': 1,
#  'reporter': 73,
#  'asked': 92,
#  'citizens': 54,
#  'united': 120,
#  'cubs': 24,
#  'head': 126,
#  'series': 66,
#  '1945': 1,
#  'dodgers': 14,
#  'blowout': 2,
#  'terrifying': 29,
#  'baseball': 64,
#  'fans': 99,
#  'onehanded': 4,
#  'scalias': 20,
#  'pelosi': 67,
#  'throws': 40,
#  'cold': 41,
#  'water': 152,
#  'tax': 427,
#  'extenders': 2,
#  'wire': 7,
#  'common': 90,
#  'good': 347,
#  'moves': 76,
#  'block': 103,
#  'budget': 135,
#  'undercuts': 4,
#  'fight': 406,
#  'cancer': 208,
#  'remarkably': 2,
#  'simple': 103,
#  'effective': 28,
#  'combat': 35,
#  'hide': 40,
#  'seek': 74,
#  'jiang': 1,
#  'wen': 1,
#  'months': 70,
#  'trumprussia': 21,
#  'stories': 58,
#  'changed': 69,
#  'minds': 24,
#  'emails': 91,
#  'watergate': 12,
#  'democracys': 3,
#  'finest': 2,
#  'hour': 18,
#  'likes': 22,
#  'frontrunner': 8,
#  'opens': 56,
#  'greatest': 53,
#  'political': 214,
#  'regret': 15,
#  'video': 302,
#  'aol': 6,
#  'sees': 37,
#  'programmatic': 3,
#  'campaigns': 45,
#  'word': 44,
#  'mattis': 10,
#  'tillerson': 55,
#  'blank': 11,
#  'check': 51,
#  'wage': 104,
#  'illegal': 37,
#  'doctors': 87,
#  'thrive': 9,
#  'obamas': 269,
#  'undermine': 17,
#  'rules': 195,
#  'dialogue': 9,
#  'hope': 114,
#  'unwillingness': 1,
#  'directly': 7,
#  'denounce': 17,
#  'supremacy': 30,
#  ...}

# %%
len(vocab)
num_words = [0 for i in range(max(vocab.values())+1)] 
freq = [i for i in range(max(vocab.values())+1)] 
for key in vocab:
    num_words[vocab[key]]+=1

# %%
cutoff_freq = 2
num_words_above_cutoff = len(vocab)-sum(num_words[0:cutoff_freq]) 
print("Number of words with frequency higher than cutoff frequency({}) :".format(cutoff_freq),num_words_above_cutoff)
# Out:
# Number of words with frequency higher than cutoff frequency(2) : 15754

# %%
features = []
for key in vocab:
    if vocab[key] >=cutoff_freq:
        features.append(key)

# %%
len(features)
import numpy as np

# %%
# To represent training data as word vector counts
X_train_dataset = np.zeros((len(X_train),len(features)))
# This can take some time to complete
for i in range(len(X_train)):
    #print(i) # Uncomment to see progress
    word_list = [ word.strip() for word in X_train[i].split()]
    for word in word_list:
        if word in features:
            X_train_dataset[i][features.index(word)] += 1

# %%
# To represent test data as word vector counts
X_test_dataset = np.zeros((len(X_test),len(features)))
# This can take some time to complete
for i in range(len(X_test)):
    # print(i) # Uncomment to see progress
    word_list = [ word.strip() for word in X_test[i].split()]
    for word in word_list:
        if word in features:
            X_test_dataset[i][features.index(word)] += 1

# %%
import os
import string
import numpy as np
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.naive_bayes import MultinomialNB

# %%
# Implementing Multinomial Naive Bayes from scratch
class MultinomialNaiveBayes:
    
    def __init__(self):
        # count is a dictionary which stores several dictionaries corresponding to each news category
        # each value in the subdictionary represents the freq of the key corresponding to that news category 
        self.count = {}
        # classes represents the different news categories
        self.classes = None
    
    def fit(self,X_train,Y_train):
        # This can take some time to complete       
        self.classes = set(Y_train)
        for class_ in self.classes:
            self.count[class_] = {}
            for i in range(len(X_train[0])):
                self.count[class_][i] = 0
            self.count[class_]['total'] = 0
            self.count[class_]['total_points'] = 0
        self.count['total_points'] = len(X_train)
        
        for i in range(len(X_train)):
            for j in range(len(X_train[0])):
                self.count[Y_train[i]][j]+=X_train[i][j]
                self.count[Y_train[i]]['total']+=X_train[i][j]
            self.count[Y_train[i]]['total_points']+=1
    
    def __probability(self,test_point,class_):
        
        log_prob = np.log(self.count[class_]['total_points']) - np.log(self.count['total_points'])
        total_words = len(test_point)
        for i in range(len(test_point)):
            current_word_prob = test_point[i]*(np.log(self.count[class_][i]+1)-np.log(self.count[class_]['total']+total_words))
            log_prob += current_word_prob
        
        return log_prob
    
    
    def __predictSinglePoint(self,test_point):
        
        best_class = None
        best_prob = None
        first_run = True
        
        for class_ in self.classes:
            log_probability_current_class = self.__probability(test_point,class_)
            if (first_run) or (log_probability_current_class > best_prob) :
                best_class = class_
                best_prob = log_probability_current_class
                first_run = False
                
        return best_class
        
  
    def predict(self,X_test):
        # This can take some time to complete
        Y_pred = [] 
        for i in range(len(X_test)):
        # print(i) # Uncomment to see progress
            Y_pred.append( self.__predictSinglePoint(X_test[i]) )
        
        return Y_pred
    
    def score(self,Y_pred,Y_true):
        # returns the mean accuracy
        count = 0
        for i in range(len(Y_pred)):
            if Y_pred[i] == Y_true[i]:
                count+=1
        return count/len(Y_pred)

# %%
import time
from sklearn.metrics import classification_report, confusion_matrix
clf2 = MultinomialNaiveBayes()
start_time=time.time()
clf2.fit(X_train_dataset,Y_train)
time_to_train=time.time()-start_time
print("Time taken for training: "+str(time_to_train)+" seconds")
print(" ")
Y_test_pred = clf2.predict(X_test_dataset)
our_score_test = clf2.score(Y_test_pred,Y_test)  
print("Overall accuracy score of model :",our_score_test)
print(" ")
print("category wise accuracy score and classification report ")
print(classification_report(Y_test, Y_test_pred))
print(" ")
print("----------confusion matrix for classification----------")
print(" ")
print(confusion_matrix(Y_test, Y_test_pred))
# Out:
# Time taken for training: 1602.1095197200775 seconds
#
# Overall accuracy score of model : 0.8026070763500931
#
# category wise accuracy score and classification report
#               precision    recall  f1-score   support
#
#            1       0.66      0.46      0.54       643
#            2       0.70      0.55      0.62       584
#            3       0.70      0.78      0.74       418
#            4       0.81      0.78      0.80       619
#            5       0.75      0.49      0.59       383
#            6       0.85      0.92      0.88      4937
#            7       0.73      0.75      0.74      1008
#
#     accuracy                           0.80      8592
#    macro avg       0.74      0.67      0.70      8592
# weighted avg       0.80      0.80      0.80      8592
#
#
# ----------confusion matrix for classification----------
#
# [[ 294    8    8   15    4  209  105]
#  [  12  324    7   24    9  168   40]
#  [   4    4  326   10    3   61   10]
#  [   5   16   18  483    5   69   23]
#  [   9   13    9    5  186  140   21]
#  [  92   90   81   37   32 4529   76]
#  [  29   11   15   21    9  169  754]]
